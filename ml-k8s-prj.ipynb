# %%
import os
print("Current Path:", os.getcwd())
# Out:
# Current Path: /mnt/c/Users/Jashanpreet/DSAbtechish/ml-k8s-project

# %%
import os
os.system("minikube start")
# Out:
# * minikube v1.38.1 on Ubuntu 24.04 (kvm/amd64)
# * Using the docker driver based on existing profile
# * Starting "minikube" primary control-plane node in "minikube" cluster
# * Pulling base image v0.0.50 ...
# * Enabled addons:
# * Verifying Kubernetes components...
#
# * Starting "minikube-m02" worker node in "minikube" cluster
# * Pulling base image v0.0.50 ...
# * Found network options:
#   - NO_PROXY=192.168.49.2
#   - env NO_PROXY=192.168.49.2
# * Verifying Kubernetes components...
# * Done! kubectl is now configured to use "minikube" cluster and "default" namespace by default
# 0

# %%
os.system("kubectl get nodes")
# Out:
# NAME           STATUS   ROLES           AGE   VERSION
# minikube       Ready    control-plane   9d    v1.35.1
# minikube-m02   Ready    <none>          9d    v1.35.1
# 0

# %%
import os
os.system("cd src && python train.py")
# Out:
# Loaded data: (5812, 5)
# Processed data: (5812, 6)
#
# Training RandomForest...
# RandomForest Accuracy: 0.944969905417025
#               precision    recall  f1-score   support
#
#            0       0.95      0.67      0.79       175
#            1       0.94      0.99      0.97       988
#
#     accuracy                           0.94      1163
#    macro avg       0.95      0.83      0.88      1163
# weighted avg       0.95      0.94      0.94      1163
#
#
# Training DecisionTree...
# DecisionTree Accuracy: 0.944969905417025
#               precision    recall  f1-score   support
#
#            0       0.95      0.67      0.79       175
#            1       0.94      0.99      0.97       988
#
#     accuracy                           0.94      1163
#    macro avg       0.95      0.83      0.88      1163
# weighted avg       0.95      0.94      0.94      1163
#
#
# Training LogisticRegression...
# LogisticRegression Accuracy: 0.9363714531384351
# ...

# %%
# !cd api && python app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: on
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
os.system("python ml_scheduler.py")
# Out:
# pod/ml-pod-1777041249 created
#
# 📊 NODE ANALYSIS
# ...
#
# Node: minikube
# CPU: 4.361, Memory: 1709.0
# ML Prediction: node2
# Score: 0.64
#
# Node: minikube-m02
# CPU: 3.879, Memory: 588.0
# ML Prediction: node2
# Score: 2.95
#
# 🎯 SELECTED NODE: minikube-m02
# 🏆 Score: 2.95
# 🧠 Reason: Lowest CPU usage, Memory within safe limit
# 🚀 Deployed pod ml-pod-1777041249 on minikube-m02
#
# 📈 METRICS
# Pod Distribution: {'minikube-m02': 11, 'minikube': 12}
# Scheduling Time: 3.0655
#
# ✅ ML Scheduling Completed
# 0

# %%
os.system("kubectl get pods -o wide")
# Out:
# NAME                                      READY   STATUS    RESTARTS         AGE     IP            NODE           NOMINATED NODE   READINESS GATES
# cpu-loader-2-deployment-b5f7754c6-fkcnh   1/1     Running   34 (3m16s ago)   3d20h   10.244.1.26   minikube-m02   <none>           <none>
# cpu-loader-2-deployment-b5f7754c6-lqpht   1/1     Running   33 (5m7s ago)    3d20h   10.244.1.25   minikube-m02   <none>           <none>
# cpu-loader-2-deployment-b5f7754c6-mgcgg   1/1     Running   34 (4m17s ago)   3d20h   10.244.0.38   minikube       <none>           <none>
# cpu-loader-2-deployment-b5f7754c6-mmcfh   1/1     Running   35 (4m33s ago)   3d20h   10.244.0.37   minikube       <none>           <none>
# cpu-loader-2-deployment-b5f7754c6-zmb9v   1/1     Running   35 (4m27s ago)   3d20h   10.244.1.22   minikube-m02   <none>           <none>
# cpu-loader-deployment-6df58f49b6-r46b4    1/1     Running   5 (4m34s ago)    3d20h   10.244.0.32   minikube       <none>           <none>
# ...

# %%
os.system("streamlit run app_ui.py &")
# Out:
# 0
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://172.26.136.95:8502
# gio: http://localhost:8502: Operation not supported
